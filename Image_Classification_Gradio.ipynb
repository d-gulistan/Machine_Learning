# %% [markdown]
# ### **Image Classification with a UI Interface**
#
# In this notebook, I create a customizable web-based GUI with Gradio where we can draw digits (0-9) to test a simple image classification model based on the MNIST dataset.

# %%
# !pip install -q gradio

# %%
import tensorflow as tf
import gradio as gr

# %%
# I load the MNIST dataset.
from tensorflow.keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
print('x_train shape: ', x_train.shape)
print('y_train shape: ', y_train.shape)
print('x_test shape: ', x_test.shape)
print('y_test shape: ', y_test.shape)
# Out:
# x_train shape:  (60000, 28, 28)
# y_train shape:  (60000,)
# x_test shape:  (10000, 28, 28)
# y_test shape:  (10000,)

# %%
# I rescale the training and test data set.
x_train = x_train / 255.0, 
x_test = x_test / 255.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense

# I define the architecture of the NN model.
model = Sequential([
  Flatten(input_shape=(28, 28)),
  Dense(128,activation='elu'),
  Dense(128,activation='elu'),
  Dense(10, activation='softmax')
])

# I configure the model for training.
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# I train the model.
model.fit(x_train, y_train,
          validation_data=(x_test, y_test),
          epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3986 - accuracy: 0.8830 - val_loss: 0.1200 - val_accuracy: 0.9629
# Epoch 2/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1185 - accuracy: 0.9639 - val_loss: 0.0921 - val_accuracy: 0.9719
# Epoch 3/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0733 - accuracy: 0.9772 - val_loss: 0.0836 - val_accuracy: 0.9724
# Epoch 4/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0562 - accuracy: 0.9825 - val_loss: 0.0895 - val_accuracy: 0.9733
# Epoch 5/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0428 - accuracy: 0.9864 - val_loss: 0.0733 - val_accuracy: 0.9791
# Epoch 6/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0330 - accuracy: 0.9894 - val_loss: 0.0734 - val_accuracy: 0.9790
# Epoch 7/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0253 - accuracy: 0.9911 - val_loss: 0.0944 - val_accuracy: 0.9757
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0251 - accuracy: 0.9918 - val_loss: 0.0877 - val_accuracy: 0.9790
# Epoch 9/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0212 - accuracy: 0.9927 - val_loss: 0.0933 - val_accuracy: 0.9798
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0180 - accuracy: 0.9939 - val_loss: 0.0916 - val_accuracy: 0.9779

# %%
# I evaluate the performance of the test set.
accuracy = model.evaluate(x_test, y_test)

print('Test set accuracy: ', accuracy * 100)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0916 - accuracy: 0.9779
# Test set accuracy:  [0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0.09157952666282654, 0.9779000282287598, 0. ...

# %%
# In order to create the web-based GUI, we need to define the prediction function, the input UI, and the output UI.
def recognize_digit(img):
    prediction = model.predict(img).tolist()[0]
    return {str(i): prediction[i] for i in range(10)}
    
sketchpad = gr.inputs.Sketchpad()
label = gr.outputs.Label(num_top_classes=3)
gr.Interface(recognize_digit,
             inputs=sketchpad,
             outputs=label,
             live=True,
             capture_session=True).launch(share=True, debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# This share link will expire in 24 hours. If you need a permanent link, email support@gradio.app
# Running on External URL: https://21412.gradio.app
# Interface loading below...
#         <iframe
#             width="1000"
#             height="500"
#             src="https://21412.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
